# %%
import selenium

# %%
from selenium import webdriver as wb
from time import sleep

# %%
driver = wb.Chrome('chromedriver.exe')
driver.get('https://www.etsy.com/in-en/listing/482107133/mandala-posts-zen-small-stud-art-mandala?ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=&ref=sr_gallery-1-3')

# %%
clickob=driver.find_element_by_xpath('//*[@id="same-listing-reviews-panel"]/div')

# %%
lst = []

# %%
for i in range(4):
    li = driver.find_element_by_xpath('//*[@id="review-preview-toggle-'+str(i)+'"]')
    print(li.text)
    lst.append(li.text)
# Out:
# Love these earrings! I lost one while snorkeling in Jamaica and I love them so much I ordered another pair! Fast shipping! Adorable packaging!
# Beautiful jewelry!! Piece is just as advertised. Shipped in a timely manner. Will definitely buy from this vendor again.
# They are beautiful!
# I love these earrings! I wear them all the time. They make my outfits more fun! You can still have some style fun during quarantine with these 😊

# %%
condition = True
lst = []
driver.find_element_by_css_selector('#reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(2)').click()
for i in range(1,13):
    
    #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
    #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(5)
    try:
    
        
        for j in range(0,4):
            li = driver.find_element_by_css_selector('#review-preview-toggle-'+str(j))
            print(li.text)
            lst.append(li.text)
        if i==1:
            kk = driver.find_element_by_css_selector('#reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(6)').click()
        elif i==2:
            kk = driver.find_element_by_css_selector('#reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(6)').click()

        else:
            kk = driver.find_element_by_css_selector('#reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)').click()

        sleep(3)
    except:
        print(i)
'''
1 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(2)
2 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(3)
3 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
4 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
5 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
6 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
7 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
8 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
9 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
10 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
11 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
12 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(4)
#1 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(6)
#2 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(6)
#3 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#4 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#5 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#6 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#7 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#8 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#9 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#10 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#11 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#12 #reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(7)
#reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(6) > a
#reviews > div.wt-flex-xl-5.wt-flex-wrap > nav > ul > li:nth-child(6) > a
'''
# Out:
# Love these earrings! I lost one while snorkeling in Jamaica and I love them so much I ordered another pair! Fast shipping! Adorable packaging!
# Beautiful jewelry!! Piece is just as advertised. Shipped in a timely manner. Will definitely buy from this vendor again.
# They are beautiful!
# I love these earrings! I wear them all the time. They make my outfits more fun! You can still have some style fun during quarantine with these 😊
# Lovely earrings! a little boho, a little classic summer. bright colors. fast shipping. Thank you!
# Another sweet pair of mandala earrings, also light weight, low profile, and comfortable to wear. Especially happy that both these pairs of earrings are nickel-free, so that I can leave them in and forget about them. Excellent packing and shipping! Highly recommended!
# I ordered these once and dropped one down the drain putting them in the first time but I loved them so much, I ordered another pair and Im so happy I did. Very pretty! Still love them!
# ...

# %%
import pandas as pd
df = pd.DataFrame()

# %%
df['reviews']=lst

# %%
df.to_csv('final_reviews_for_ear_rings1')

# %%
df.head()
# Out:
#                                              reviews
# 0  Love these earrings! I lost one while snorkeli...
# 1  Beautiful jewelry!! Piece is just as advertise...
# 2                                They are beautiful!
# 3  I love these earrings! I wear them all the tim...
# 4  Lovely earrings! a little boho, a little class...

# %%
df2 = pd.read_csv('final_reviews_for_ear_rings1')

# %%
df2.head()
# Out:
#    Unnamed: 0                                            reviews
# 0           0  Love these earrings! I lost one while snorkeli...
# 1           1  Beautiful jewelry!! Piece is just as advertise...
# 2           2                                They are beautiful!
# 3           3  I love these earrings! I wear them all the tim...
# 4           4  Lovely earrings! a little boho, a little class...

# %%
def check_review(reviewText):
    #reviewText has to be vectorised, that vectorizer is not saved yet
    #load the vectorize and call transform and then pass that to model preidctor
    #load it later

    transformer = TfidfTransformer()
    loaded_vec = CountVectorizer(decode_error="replace",vocabulary=vocab)
    reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))


    # Add code to test the sentiment of using both the model
    # [0] == negative   [1] == positive
    return pickle_model.predict(reviewText)

# %%
df2['positivity'] = df2['reviews'].apply(lambda i: check_review(i)[0])

# %%
df2.head()
# Out:
#    Unnamed: 0                                            reviews  positivity
# 0           0  Love these earrings! I lost one while snorkeli...           1
# 1           1  Beautiful jewelry!! Piece is just as advertise...           1
# 2           2                                They are beautiful!           1
# 3           3  I love these earrings! I wear them all the tim...           1
# 4           4  Lovely earrings! a little boho, a little class...           1

# %%
np.linspace(0, 1, 2)
# Out:
# array([0., 1.])

# %%
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.gridspec import GridSpec

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(1, figsize=(20,10))
the_grid = GridSpec(2, 2)

#source_labels = df2.positivity.sort_values().index
source_labels = ['positivity','negativity']

source_counts = [48,2]
cmap = plt.get_cmap('Spectral')
colors = [cmap(i) for i in np.linspace(0, 1, 2)]


plt.subplot(the_grid[0, 1], aspect=1, title='Source of Pies')

source_pie = plt.pie(source_counts, labels=source_labels, autopct='%1.1f%%', shadow=True, colors=['green','yellow'])


#plt.subplot(the_grid[0, 0], aspect=1, title='Selected Flavors of Pies')

#flavor_pie = plt.pie(flavor_counts,labels=flavor_labels, autopct='%.0f%%', shadow=True, colors=colors)

plt.suptitle('Pie Chart', fontsize=16)
plt.savefig('pie_chart.png')

plt.show()

# %%
import pickle
import dash
from dash.dependencies import Input, Output, State
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
import dash_core_components as dcc

# %%
import pandas as pd
import plotly.express as px

# %%
import webbrowser

# %%
import dash_html_components as html

# %%
app = dash.Dash()

# %%
project_name = None

# %%
def load_model():
    global df
    df = pd.read_csv('balanced_reviews.csv')
  
    global pickle_model
    file = open("pickle_model.pkl", 'rb') 
    pickle_model = pickle.load(file)

    global vocab
    file = open("feature.pkl", 'rb') 
    vocab = pickle.load(file)
    
    print(df.sample(5))

# %%
def check_review(reviewText):
    #reviewText has to be vectorised, that vectorizer is not saved yet
    #load the vectorize and call transform and then pass that to model preidctor
    #load it later

    transformer = TfidfTransformer()
    loaded_vec = CountVectorizer(decode_error="replace",vocabulary=vocab)
    reviewText = transformer.fit_transform(loaded_vec.fit_transform([reviewText]))


    # Add code to test the sentiment of using both the model
    # [0] == negative   [1] == positive
    return pickle_model.predict(reviewText)

# %%
def open_browser():
    webbrowser.open_new('http://127.0.0.1:8050/')

# %%
df1 = pd.read_csv('final_reviews_for_ear_rings1')
df1['positivity'] = df1['reviews'].apply(lambda i:check_review(i)[0])
count1 = df1['positivity'].value_counts()
print(count1[1])
count1
# Out:
# 47
# 1    47
# 0     1
# Name: positivity, dtype: int64

# %%
def create_app_ui():

    main_layout = html.Div([
        html.H1(children='Sentiments Analysis with Insights', id='Main_title',style={'text-align':'center','fontSize':50}),
        html.Div([
            html.Img(src = app.get_asset_url('review.png'))
        ], style={'textAlign': 'center'}),
        html.Div(style={'backgroundColor':'#52b7e9'},children=[
            html.H3(children='Pie Chart of reviews', id='sub_heading1',style={'color':'red','fontSize':30,'text-align':'center'}),
            dcc.Graph(figure=px.pie(df1,values=[count1[1],count1[0]],names=['positive_reviews','negative reviews'],hole=.4,opacity=1))
            #dcc.Graph(figure=px.histogram(df1,x='positivity', color=['positive_reviews','negative reviews'], marginal="rug"))
        ], className='piegraph_contents'),
        html.Div(style={'backgroundColor':'#111111'}, children=[
        html.Div([
            html.H3(children='Check reviews using dropdown list', id='sub_heading2',style={'color':'#7FDBFF','fontSize':20,'text-align':'center'}),

            dcc.Dropdown(
                id='dropdown',
                options=[{'label':i,'value':i} for i in df1["reviews"][:40]],
                value='I loved the shoes'

            ),
            html.Br(),
            html.Button(children='Find Review', id='button_review',n_clicks=0,style={'backgroundColor':'yellow','fontSize':20,'width':'10%','height':'40px'}),
            html.H1(children=None, id='result',style={'color':'#efcccf','text-align':'center'}),
        ], className='Dropdown_list'),
        html.Div([
            html.H3(children='Enter review in textbox and check', id='sub_heading3',style={'color':'#7FDBFF','fontSize':20,'text-align':'center'}),
            
            dcc.Textarea(
                
                id='textarea_review',
                placeholder='Enter the review here...',
                #value='My daughter loves these shoes',
                style={'width': '100%', 'height': 70,'backgroundColor':'#99ff99'}
                ),
            html.Br(),
            html.Button(children='Find Review',id='button_review1',n_clicks=0,style={'backgroundColor':'yellow','fontSize':20,'width':'10%','height':'40px'}),
            html.H1(children=None, id='result1',style={'color':'#efcccf','text-align':'center'}),
            
        ], className='text_review')
        ])
    ], className='main_window')
    
    return main_layout

# %%
@app.callback(
    Output('result', 'children'),
    [
    Input('button_review', 'n_clicks'),
    State('dropdown','value')
    ]
    )
def update_app_ui(n_click,textarea_value):
    
    print("Data Type  = ", str(type(textarea_value)))
    print("Value      = ", str(textarea_value))

    
    result_list = check_review(textarea_value)
    if n_click > 0:
        if (result_list[0] == 0 ):
            result = 'Review is : Negative'
        elif (result_list[0] == 1 ):
            result = 'Review is : Positive'
        else:
            result = 'Review is : Unknown'
        
    return result
@app.callback(
    Output('result1', 'children'),
    [
    Input('button_review1','n_clicks'),
    Input('textarea_review', 'value')
    ]
    )
def update_app_ui1(n_clicks,textarea_value):
    
    print("Data Type  = ", str(type(textarea_value)))
    print("Value      = ", str(textarea_value))
    result_list = check_review(textarea_value)

    if n_clicks>0:
        print(result_list)
        if (result_list[0] == 0 ):
            result = 'Review is : Negative'
        elif (result_list[0] == 1 ):
            result = 'Review is : Positive'
        else:
            result = 'Review is : Unknown'

    return result

# %%
# Main Function to control the Flow of your Project
def main():
    load_model()    
    open_browser()
    

    global project_name
    project_name = "Sentiments Analysis with Insights" 
      
    global app
    app.layout = create_app_ui()
    app.title = project_name
    # go to https://www.favicon.cc/ and download the ico file and store in assets directory 
    app.run_server() # debug=True
  
    print("This would be executed only after the script is closed")
    app = None
    project_name = None

# %%
if __name__ == '__main__':
    main()
# Out:
#         overall                                         reviewText  \
# 454904        1  i was given a pair that was dirty and without ...
# 724202        4  Nothing much to say really .  I ordered it for...
# 34936         3  The arms fit a little snugg but the chest and ...
# 363373        5  I needed a hat for a tea party and this will w...
# 6216          4       One of the most comfortable shoes I've owned
#
#                                                   summary
# 454904  i was given a pair that was dirty and without ...
# 724202                                               Nice
# 34936   ... little snugg but the chest and hip part fa...
# 363373                                     Nice facinator
# 6216                                           Four Stars
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# ...
